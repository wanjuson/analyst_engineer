# %%
## 생존분석
# https://data-newbie.tistory.com/920#%EC%83%9D%EC%A1%B4-%EB%B6%84%EC%84%9D-%EB%B6%84%EC%84%9D-%EB%B0%A9%EB%B2%95%EB%A1%A0

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('C:/adp/data/employee.csv')
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
## Load lung cancer data
library(survival)
data(cancer)
 
## status == 2 이 죽은 경우를 나타냄 
#생존 분석을 위해서 Survival Object 생성 : +라고 붙는 변수는 censor된 데이터임 
cancer$SurvObj <- with(cancer, Surv(time, status == 2))
head(cancer)
 
attach(cancer)
 
#Kaplan-Meier estimator without grouping
## Kaplan-Meier estimator. The "log-log" confidence interval is preferred.
km.as.one <- survfit(SurvObj ~ 1, data = cancer, conf.type = "log-log")
km.as.one
# Out:
#   File "C:\Users\신주현\AppData\Local\Temp\ipykernel_32080\1955735674.py", line 7
#     cancer$SurvObj <- with(cancer, Surv(time, status == 2))
#           ^
# SyntaxError: invalid syntax

# %%
from lifelines import KaplanMeierFitter

kmf = KaplanMeierFitter()
kmf.fit(durations=df['YearsAtCompany'], event_observed=df['Attrition'])

kmf.survival_function_.plot(figsize=(8,5))
plt.title('Survival Curve estimated with Kaplan-Meier Fitter')
plt.show()

kmf.plot_survival_function(figsize=(8,5))
plt.title('Survival Curve estimated with Kaplan-Meier Fitter with confidence intervals')
plt.show()
# Out:
# c:\Users\신주현\AppData\Local\Programs\Python\Python37\lib\site-packages\lifelines\utils\__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\신주현\AppData\Local\Programs\Python\Python37\lib\site-packages\lifelines\utils\__init__.py in check_nans_or_infs(df_or_array)
#    1180     try:
# -> 1181         infs = np.isinf(df_or_array)
#    1182     except TypeError:
#
# TypeError: ufunc 'isinf' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
pip install lifelines
# Out:
# ...
#      -------------------------------------- 349.7/349.7 kB 1.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 77.1/77.1 kB 1.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 48.9/48.9 kB 823.6 kB/s eta 0:00:00
# ...
#      -------------------------------------- 840.9/840.9 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# ...
#   Running setup.py install for future: started
#   Running setup.py install for future: finished with status 'done'
#   Running setup.py install for autograd-gamma: started
#   Running setup.py install for autograd-gamma: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
