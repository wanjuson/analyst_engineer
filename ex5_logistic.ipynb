# %%
# 고객 3,500명에 대한 학습용 데이터(y_train.csv, X_train.csv)를 이용하여 성별예측 모형을 만든 후,
# 이를 평가용 데이터(X_test.csv)에 적용하여 얻은 2,482명 고객의 성별 예측값(남자일 확률)을
# 다음과 같은 형식의 CSV 파일로 생성하시오.(

# %%
# ① y_train.csv : 고객의 성별 데이터 (학습용), CSV 형식의 파일
# ② X_train.csv, X_test.csv : 고객의 상품구매 속성 (학습용 및 평가용), CSV 형식의 파일

# %%
# 1.데이터 불러오기
import pandas as pd
x_train = pd.read_csv('X_train.csv', encoding = 'cp949')
x_train['환불금액2'] = x_train['환불금액']
t1 = x_test['환불금액'].mean()
x_train['환불금액2'][x_train['환불금액2'].isna()] = t1
x_train
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       cust_id       총구매액      최대구매액         환불금액   주구매상품 주구매지점  내점일수  \
# 0           0   68282840   11264000    6860000.0      기타   강남점    19
# 1           1    2136000    2136000     300000.0     스포츠   잠실점     2
# 2           2    3197000    1639000          NaN  남성 캐주얼   관악점     2
# 3           3   16077620    4935000          NaN      기타   광주점    18
# 4           4   29050000   24000000          NaN      보석  본  점     2
# 5           5   11379000    9552000     462000.0    디자이너   일산점     3
# 6           6   10056000    7612000    4582000.0    시티웨어   강남점     5
# 7           7  514570080   27104000   29524000.0      명품  본  점    63
# ...

# %%
# 데이터 백업
x_train['주구매상품2'] = x_train['주구매상품']
x_train['주구매지점2'] = x_train['주구매지점']
# 범주형 변수를 숫자형으로 변환
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
fe1 = ['주구매상품', '주구매지점']
for i in fe1:
    x_train[i] = label.fit_transform(x_train[i])

# %%
x_train.tail()
# Out:
#       cust_id       총구매액     최대구매액       환불금액  주구매상품  주구매지점  내점일수   내점당구매건수  \
# 3495     3495    3175200   3042900        NaN      3      8     1  2.000000
# 3496     3496   29628600   7200000  6049600.0     22      9     8  1.625000
# 3497     3497      75000     75000        NaN     32     21     1  1.000000
# 3498     3498    1875000   1000000        NaN     41      8     2  1.000000
# 3499     3499  263101550  34632000  5973000.0      5      8    38  2.421053
#
#         주말방문비율  구매주기         환불금액2 주구매상품2 주구매지점2
# 3495  1.000000     0  2.554716e+07     골프   본  점
# 3496  0.461538    40  6.049600e+06   시티웨어   부산본점
# 3497  0.000000     0  2.554716e+07   주방용품    창원점
# 3498  0.000000    39  2.554716e+07    화장품   본  점
# 3499  0.467391     8  5.973000e+06     기타   본  점

# %%
x1_train = x_train[['총구매액', '최대구매액', '환불금액2', '내점일수', '내점당구매건수'
                    , '주말방문비율', '구매주기', '주구매상품', '주구매지점']]
x1_train.tail()
# Out:
#            총구매액     최대구매액         환불금액2  내점일수   내점당구매건수    주말방문비율  구매주기  \
# 3495    3175200   3042900  2.554716e+07     1  2.000000  1.000000     0
# 3496   29628600   7200000  6.049600e+06     8  1.625000  0.461538    40
# 3497      75000     75000  2.554716e+07     1  1.000000  0.000000     0
# 3498    1875000   1000000  2.554716e+07     2  1.000000  0.000000    39
# 3499  263101550  34632000  5.973000e+06    38  2.421053  0.467391     8
#
#       주구매상품  주구매지점
# 3495      3      8
# 3496     22      9
# 3497     32     21
# 3498     41      8
# 3499      5      8

# %%
x_test = pd.read_csv('X_test.csv', encoding = 'cp949')
x_test['환불금액2'] = x_test['환불금액']
t2 = x_test['환불금액'].mean()
x_test['환불금액2'][x_test['환불금액2'].isna()] = t2
x_test
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#       cust_id       총구매액      최대구매액        환불금액   주구매상품 주구매지점  내점일수  \
# 0        3500   70900400   22000000   4050000.0      골프  부산본점    13
# 1        3501  310533100   38558000  48034700.0     농산물   잠실점    90
# 2        3502  305264140   14825000  30521000.0    가공식품  본  점   101
# 3        3503    7594080    5225000         NaN    주방용품  부산본점     5
# 4        3504    1795790    1411200         NaN     수산품  청량리점     3
# 5        3505   13000000    2160000         NaN     화장품   잠실점     5
# 6        3506  420892520   69920000  39566000.0      기타  본  점   144
# 7        3507    1152000    1152000         NaN     스포츠   분당점     1
# ...

# %%
# 데이터 백업
x_test['주구매상품2'] = x_test['주구매상품']
x_test['주구매지점2'] = x_test['주구매지점']
# 범주형 변수를 숫자형으로 변환
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
fe1 = ['주구매상품', '주구매지점']
for i in fe1:
    x_test[i] = label.fit_transform(x_test[i])
x_test
# Out:
#       cust_id       총구매액      최대구매액        환불금액  주구매상품  주구매지점  내점일수  \
# 0        3500   70900400   22000000   4050000.0      3      9    13
# 1        3501  310533100   38558000  48034700.0      9     19    90
# 2        3502  305264140   14825000  30521000.0      0      8   101
# 3        3503    7594080    5225000         NaN     31      9     5
# 4        3504    1795790    1411200         NaN     19     22     3
# 5        3505   13000000    2160000         NaN     40     19     5
# 6        3506  420892520   69920000  39566000.0      5      8   144
# 7        3507    1152000    1152000         NaN     20     11     1
# 8        3508    4825000    4825000         NaN     40     18     1
# 9        3509  110787210   19255600  23062000.0      0      5    28
# 10       3510  107894360   19668000  29502000.0     11      8    21
# 11       3511    4500000    4500000    750000.0      5      0     3
# 12       3512    2467010     280000    280000.0      0      8    23
# ...

# %%
x1_test = x_test[['총구매액', '최대구매액', '환불금액2', '내점일수', '내점당구매건수'
                  , '주말방문비율', '구매주기', '주구매상품', '주구매지점']]
x1_test.tail()
# Out:
#            총구매액     최대구매액         환불금액2  내점일수   내점당구매건수    주말방문비율  구매주기  \
# 2477   82581500  23976000  2.554716e+07     8  1.750000  0.642857    40
# 2478     480000    480000  2.554716e+07     1  1.000000  0.000000     0
# 2479  260003790  25750000  2.554716e+07    19  3.736842  0.915493    18
# 2480   88991520  18120000  2.554716e+07     5  3.600000  0.444444    60
# 2481     623700    209000  2.554716e+07     2  5.000000  0.000000    31
#
#       주구매상품  주구매지점
# 2477      3      9
# 2478     17      2
# 2479      6      8
# 2480     26      8
# 2481      0     15

# %%
# t1 = x_test['환불금액'].mean()

# %%
y1_train = pd.read_csv('y_train.csv', encoding = 'cp949')
y1_train.tail()
# Out:
#       cust_id  gender
# 3495     3495       1
# 3496     3496       1
# 3497     3497       0
# 3498     3498       0
# 3499     3499       0

# %%
# 2.데이터 전처리
# z-score 정규화
from sklearn.preprocessing import StandardScaler
stand_scale = StandardScaler()
# train
stand_scale.fit(x1_train)
x1_train_stand_scale = stand_scale.transform(x1_train)
pd.DataFrame(x1_train_stand_scale).describe()
# Out:
#                   0             1             2             3             4  \
# count  3.500000e+03  3.500000e+03  3.500000e+03  3.500000e+03  3.500000e+03
# mean  -4.409171e-17 -4.838986e-17  3.116237e-16  2.518303e-16 -2.346536e-16
# std    1.000143e+00  1.000143e+00  1.000143e+00  1.000143e+00  1.000143e+00
# min   -8.829091e-01 -7.082781e-01 -8.990359e-01 -6.718072e-01 -9.596611e-01
# 25%   -5.332182e-01 -5.248643e-01 -1.171158e-01 -6.350034e-01 -6.110034e-01
# 50%   -3.896215e-01 -3.072187e-01  1.816097e-02 -4.141802e-01 -2.623457e-01
# 75%    8.923657e-02  1.031100e-01  1.816097e-02  2.114855e-01  2.824320e-01
# max    1.364826e+01  2.147585e+01  1.934512e+01  9.780490e+00  1.006664e+01
#
#                   5             6             7             8
# count  3.500000e+03  3.500000e+03  3.500000e+03  3.500000e+03
# mean   1.402687e-16 -1.220294e-16 -6.236281e-17 -8.333017e-17
# std    1.000143e+00  1.000143e+00  1.000143e+00  1.000143e+00
# ...

# %%
# test
x1_test_stand_scale = stand_scale.transform(x1_test)
pd.DataFrame(x1_test_stand_scale).describe()
# Out:
#                  0            1            2            3            4  \
# count  2482.000000  2482.000000  2482.000000  2482.000000  2482.000000
# mean      0.055714     0.065845     0.018161     0.009687    -0.008146
# std       1.059517     1.095706     1.263996     0.955943     0.917606
# min      -0.791270    -1.785189    -0.898878    -0.671807    -0.959661
# 25%      -0.531201    -0.524572    -0.215723    -0.635003    -0.567421
# 50%      -0.375588    -0.278598     0.018161    -0.377376    -0.211292
# 75%       0.211069     0.206728     0.018161     0.275892     0.282432
# max      16.939470    17.930622    30.396828     7.461847     6.819764
#
#                  5            6            7            8
# count  2482.000000  2482.000000  2482.000000  2482.000000
# mean     -0.046372    -0.027166    -0.068490     0.041715
# std       0.975457     0.974282     0.951981     1.012016
# min      -1.060530    -0.846966    -1.122438    -1.904703
# ...

# %%
# 3. 데이터 분석
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
model1.fit(x1_train_stand_scale, y1_train['gender'])
# train
model1.score(x1_train_stand_scale, y1_train['gender']) # R2
# Out:
# 0.634

# %%
# test 데이터 예측
prob_test = model1.predict_proba(x1_test_stand_scale)
prob_test[:,0]
# Out:
# array([0.51340772, 0.79840195, 0.87145211, ..., 0.58686714, 0.631666  ,
#        0.56250636])

# %%
# 4. 분석결과 저장
x_test['custid'] = x_test['cust_id']
result1 = x_test[['custid']]

# %%
result1['gender'] = prob_test[:,0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
result1.to_csv('ex5_logistic1.csv')

# %%
help('sklearn.preprocessing')
# Out:
# Help on package sklearn.preprocessing in sklearn:
#
# NAME
#     sklearn.preprocessing
#
# DESCRIPTION
#     The :mod:`sklearn.preprocessing` module includes scaling, centering,
#     normalization, binarization and imputation methods.
#
# PACKAGE CONTENTS
#     _function_transformer
#     data
#     imputation
#     label
#     tests (package)
#
# CLASSES
#     sklearn.base.BaseEstimator(builtins.object)
#         sklearn.preprocessing._function_transformer.FunctionTransformer(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#         sklearn.preprocessing.data.Binarizer(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#         sklearn.preprocessing.data.KernelCenterer(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#         sklearn.preprocessing.data.MaxAbsScaler(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#         sklearn.preprocessing.data.MinMaxScaler(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
# ...
