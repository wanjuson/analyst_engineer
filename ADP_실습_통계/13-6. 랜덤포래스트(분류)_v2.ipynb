# %% [markdown]
# ## 랜덤 포레스트 (분류)
#
# <br>
#
# <b>분류의 경우</b>
# > sklearn.ensemble.RandomForestClassifier(...)
#
#
# - n_estimators : RandomForest에서 나무의 수 (int, default = 100)<br>
# - criterion : 분할의 품질을 측정하는 방법 ({“gini”, “entropy”}, default=”gini”)<br>
# - max_depth : 나무의 최대 깊이. (int, default = None)<br>
# &emsp; &emsp;&emsp; &emsp;&emsp; None이면 모든 잎이 순수하거나 잎에 min_sample_split 미만의 샘플만 존재할 때까지 노드 확장<br>
# - min_samples_split : 내부 노드를 분할하는 데 필요한 최소 샘플 수 (int or float, default=2)<br>
# - min_samples_leaf : 리프 노드에 있어야하는 최소 샘플 수 (int or float, default=1)<br>
# - max_leaf_nodes : 리프 노드의 최대 개수 (int, default = None)<br>
# &emsp;&emsp;&emsp;&emsp; &emsp; &emsp; &emsp; None이면 리프 노드 수에 제한이 없음<br>
# - bootstrap : 나무를 만들 때 부트 스트랩 샘플이 사용되는지 여부 (bool, default=True)<br>
# &emsp;&emsp;&emsp;&emsp;&emsp; False이면 전체 데이터 세트가 각 트리를 작성하는 데 사용<br>
# - oob_score : 정확도 측정을 위해 out-of-bag 샘플을 사용할지 여부 (bool, default=False)<br>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

credit = pd.read_csv("C:/adp/data/credit_final.csv")
X = credit[credit.columns.difference(['credit.rating'])]
y = credit['credit.rating']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=321)
X_train.head()
# Out:
#      account.balance  age  apartment.type  bank.credits  credit.amount  \
# 133                3   26               2             1           1453
# 464                2   24               1             1           7472
# 919                1   46               3             2           6331
# 865                3   39               3             2           1271
# 352                3   46               2             2           7629
#
#      credit.duration.months  credit.purpose  current.assets  dependents  \
# 133                      18               3               1           1
# 464                      12               4               1           1
# 919                      48               1               4           1
# 865                      15               3               4           1
# 352                      48               4               3           2
#
#      employment.duration  foreign.worker  guarantor  installment.rate  \
# 133                    1               1          1                 3
# 464                    1               1          1                 1
# 919                    4               1          1                 4
# 865                    2               1          1                 3
# 352                    4               1          1                 4
#
#      marital.status  occupation  other.credits  \
# 133               1           3              2
# 464               1           1              2
# 919               3           3              2
# 865               3           3              2
# 352               1           4              1
#
#      previous.credit.payment.status  residence.duration  savings  telephone
# 133                               2                   1        1          1
# 464                               2                   2        4          1
# 919                               3                   4        1          2
# 865                               3                   4        4          2
# 352                               3                   2        4          1

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

clf = clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print("정확도 : ", clf.score(X_test, y_test))
# Out:
# 정확도 :  0.7566666666666667

# %%
from sklearn.metrics import confusion_matrix # 오차행렬
# 정밀도, 재현율, F1 스코어 : f1_score(test_y, pred)로 사용
from sklearn.metrics import precision_score, recall_score, f1_score 

print(f"정밀도 : {precision_score(y_test, y_pred)}")
print(f"재현율 : {recall_score(y_test, y_pred)}")
print(f"F1 스코어 : {f1_score(y_test, y_pred)}")

# 오차행렬
pd.DataFrame(confusion_matrix(y_test, y_pred),
             index=['True[0]', 'True[1]'],
             columns=['Pred[0]','Pred[1]'])
# Out:
# 정밀도 : 0.7642276422764228
# 재현율 : 0.9261083743842364
# F1 스코어 : 0.8374164810690422
#          Pred[0]  Pred[1]
# True[0]       39       58
# True[1]       15      188

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_roc_curve

plot_roc_curve(clf, X_test, y_test)
plt.show()
# Out:
# C:\Users\신주현\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
clf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import GridSearchCV
# param_grid = {'max_depth':range(2,10,2) , 'min_samples_leaf':range(2,10,2)}
param_grid = {'max_depth':range(2,20,2) , 'min_samples_leaf':range(2,20,2)}
model_grid_rf = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
model_grid_rf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(2, 20, 2),
#                          'min_samples_leaf': range(2, 20, 2)})

# %%
model_grid_rf.best_estimator_.estimators_
# Out:
# [DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1186890705),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1465327000),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=668736579),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=103035315),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1509563766),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1941136558),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1902814244),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=339273006),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=564009243),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=856804450),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1513399225),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=372402533),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1966345650),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1296282247),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=510962965),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=272664326),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=902627419),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1275196570),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1553479930),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1846662866),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=599527724),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=947579923),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=370570046),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1310136055),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1444573271),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1591716232),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=481457232),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=2084400773),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1368464039),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=943982760),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=611094137),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1042664127),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1959232728),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=604657274),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=319381317),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1237894716),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1368194414),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=257046942),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1501203189),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=300735647),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=867048343),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1348198036),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1743762999),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=448440271),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1215414413),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1025115604),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1779720986),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=521776750),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=642681821),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=950071663),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=879767814),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=93340726),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=782008568),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=984279269),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1503324288),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=779019369),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=962322804),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=447316956),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=2136171450),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=728265727),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1417643548),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=838330276),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=769705002),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1312456104),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=394585058),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1011078540),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=592021467),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=128523980),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=2027143276),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1714851794),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=571679271),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1607116263),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=342259491),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=294831607),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=2054098677),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=567870887),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1780826719),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=697346381),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=28356557),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=951589378),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1671966148),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1893185551),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1629406929),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=783484070),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=21186123),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1435066624),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=251516309),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1324473266),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=899010396),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=716372379),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1736680103),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=317968598),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=508827254),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=555874324),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1059492553),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=2123330110),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=842684984),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=427542391),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1880373203),
#  DecisionTreeClassifier(max_depth=8, max_features='auto', min_samples_leaf=2,
#                         random_state=1907391395)]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_roc_curve

plot_roc_curve(model_grid_rf.best_estimator_, X_test, y_test)
plt.show()
# Out:
# C:\Users\신주현\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
## 변수의 중요도 확인
import numpy as np
importances = pd.DataFrame(np.mean([tree.feature_importances_ for tree in model_grid_rf.best_estimator_.estimators_], axis=0))
feature_importances = pd.concat([pd.DataFrame(X.columns), importances], axis=1)
feature_importances.columns=["col_name","feature_importance"]
feature_importances = feature_importances.sort_values(by="feature_importance",ascending=False).reset_index(drop=True)
feature_importances
# Out:
#                           col_name  feature_importance
# 0                  account.balance            0.151790
# 1                    credit.amount            0.138605
# 2           credit.duration.months            0.128497
# 3                              age            0.083908
# 4   previous.credit.payment.status            0.077889
# 5                          savings            0.053853
# 6                   current.assets            0.050445
# 7                   credit.purpose            0.047263
# 8              employment.duration            0.041652
# 9                 installment.rate            0.032999
# 10                  apartment.type            0.031983
# 11              residence.duration            0.031932
# 12                      occupation            0.026392
# 13                  marital.status            0.024915
# 14                   other.credits            0.018654
# 15                       guarantor            0.015268
# 16                    bank.credits            0.014630
# 17                       telephone            0.013875
# 18                      dependents            0.012474
# 19                  foreign.worker            0.002975

# %%
import matplotlib.pyplot as plt


plt.barh(feature_importances["col_name"], feature_importances["feature_importance"], align='center')

plt.xlabel('feature importance', size=15)

plt.ylabel('feature', size=15)

plt.show()
